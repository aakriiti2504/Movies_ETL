# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory = False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.sample()
# Out:
#          userId  movieId  rating   timestamp
# 8440498   86924    46578     3.0  1409586780

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 12773763  132552     4246     5.0  1025862765
# 1577708    16377     4733     3.0  1013616444
# 14730194  153198     1093     2.0   981668320
# 9440605    97434     1090     3.5  1179925341
# 6441754    66476      356     5.0   839164737

# %%
movies_metadata.sample(n = 10)
# Out:
#        adult belongs_to_collection    budget  \
# 3933   False                   NaN         0
# 13375  False                   NaN         0
# 12316  False                   NaN  70000000
# 39217  False                   NaN         0
# 42577  False                   NaN         0
# 36500  False                   NaN         0
# 24182  False                   NaN         0
# 21898  False                   NaN         0
# 20200  False                   NaN         0
# 35772  False                   NaN         0
#
#                                                   genres  \
# 3933                       [{'id': 18, 'name': 'Drama'}]
# 13375  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 12316  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 39217  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 42577                     [{'id': 28, 'name': 'Action'}]
# 36500  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 24182  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 21898                     [{'id': 27, 'name': 'Horror'}]
# 20200                      [{'id': 18, 'name': 'Drama'}]
# 35772                      [{'id': 18, 'name': 'Drama'}]
#
#                                       homepage      id    imdb_id  \
# 3933                                       NaN  220976  tt0213446
# 13375                                      NaN  141971  tt1180333
# 12316                                      NaN   10253  tt0372873
# 39217          http://www.besomebodymovie.com/  397517  tt5512872
# 42577                                      NaN  422972  tt5020372
# 36500                                      NaN   43953  tt0101927
# 24182                                      NaN  127798  tt0032321
# 21898          http://tarnolgrouppictures.com/  160897  tt2170301
# 20200                                      NaN   74549  tt1561770
# 35772  http://www.unrelatedfilm.com/index.html   29982  tt1107850
#
#       original_language               original_title  \
# 3933                 en              The Amati Girls
# 13375                fi                     Blackout
# 12316                ko                           디워
# 39217                en                  Be Somebody
# 42577                en                   Kill Ratio
# 36500                da  Fuglekrigen i Kanøfleskoven
# 24182                en                   Chad Hanna
# 21898                fr                 Barrio Tales
# 20200                en                 The Shunning
# 35772                en                    Unrelated
#
#                                                 overview  ... release_date  \
# 3933   Four sisters who disagree about everything... ...  ...   2001-01-09
# 13375  Recovering from a nail gun shot to the head an...  ...   2008-12-26
# 12316  Based on the Korean legend, unknown creatures ...  ...   2007-02-08
# 39217  Pop superstar Jordan Jaye has a big dream - he...  ...   2016-06-10
# 42577  An attack on the new President of a fledgling ...  ...   2016-12-09
# 36500  Fagin is the bad bird of an otherwise idyllic ...  ...   1990-07-01
# 24182  Country boy joins a circus in the 1840s and fa...  ...   1940-12-25
# 21898  Two American teenagers in search of cheap drug...  ...   2012-01-12
# 20200  Beautiful Katie Lapp has always felt something...  ...   2011-04-16
# 35772  A woman in an unhappy relationship takes refug...  ...   2007-10-18
#
#           revenue runtime                                   spoken_languages  \
# 3933          0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13375         0.0   108.0             [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 12316  53587404.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 39217         0.0    88.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 42577         0.0    86.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 36500         0.0    68.0             [{'iso_639_1': 'da', 'name': 'Dansk'}]
# 24182         0.0    86.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 21898         0.0    84.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 20200         0.0    88.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 35772         0.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#                 status                                            tagline  \
# 3933          Released  Four sisters who disagree about everything... ...
# 13375         Released  Which one is the first to return - memory or t...
# 12316         Released          They've made our world their battleground
# 39217         Released                                                NaN
# 42577  Post Production                            One Man versus an Army.
# 36500         Released                                                NaN
# 24182         Released  Thrilling New Millions ! Right out of the page...
# 21898         Released                          Welcome to Barrio Amigos!
# 20200         Released                                                NaN
# 35772         Released                                                NaN
#
#                     title  video vote_average vote_count
# 3933      The Amati Girls  False          0.0        0.0
# 13375            Blackout  False          6.7        3.0
# 12316  Dragon Wars: D-War  False          4.0      104.0
# 39217         Be Somebody  False          6.6       34.0
# 42577          Kill Ratio  False          3.9       13.0
# 36500    War of the Birds  False          6.3        5.0
# 24182          Chad Hanna  False          0.0        0.0
# 21898        Barrio Tales  False          4.2        5.0
# 20200        The Shunning  False          6.2       10.0
# 35772           Unrelated  False          4.9       10.0
#
# [10 rows x 24 columns]

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-df8c84c0b53b> in <module>
# ----> 1 kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
#       2 ratings = pd.read_csv(f'{file_dir}ratings.csv')
#
# NameError: name 'file_dir' is not defined

# %%
kaggle_metadata.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-fd2b8bf4007a> in <module>
# ----> 1 kaggle_metadata.dtypes
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata['adult'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cc159b74584d> in <module>
# ----> 1 kaggle_metadata['adult'].value_counts()
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ce8803c9cedc> in <module>
# ----> 1 kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-90e6ecf39c8b> in <module>
# ----> 1 kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata['video'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a7bf96dec559> in <module>
# ----> 1 kaggle_metadata['video'].value_counts()
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata['video'] == 'True'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-217a3543aa79> in <module>
# ----> 1 kaggle_metadata['video'] == 'True'
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e0ec43a3f805> in <module>
# ----> 1 kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-39800f223fbd> in <module>
# ----> 1 kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
#       2 kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
#       3 kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')
#
# NameError: name 'kaggle_metadata' is not defined

# %%
kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-78b164a7f02d> in <module>
# ----> 1 kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])
#
# NameError: name 'kaggle_metadata' is not defined

# %%
ratings.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB
# C:\Users\14197\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   """Entry point for launching an IPython kernel.

# %%
pd.to_datetime(ratings['timestamp'], unit='s')
# Out:
# 0          2015-03-09 22:52:09
# 1          2015-03-09 23:07:15
# 2          2015-03-09 22:52:03
# 3          2015-03-09 22:52:26
# 4          2015-03-09 22:52:36
#                    ...
# 26024284   2009-10-31 23:26:04
# 26024285   2009-10-31 23:33:52
# 26024286   2009-10-31 23:29:24
# 26024287   2009-11-01 00:06:30
# 26024288   2009-10-31 23:30:58
# Name: timestamp, Length: 26024289, dtype: datetime64[ns]

# %%
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')

# %%
pd.options.display.float_format = '{:20,.2f}'.format
ratings['rating'].plot(kind='hist')
ratings['rating'].describe()
# Out:
# count          26,024,289.00
# mean                    3.53
# std                     1.07
# min                     0.50
# 25%                     3.00
# 50%                     3.50
# 75%                     4.00
# max                     5.00
# Name: rating, dtype: float64

# %%
movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-217c7088e47b> in <module>
# ----> 1 movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])
#
# NameError: name 'wiki_movies_df' is not defined

# %%
movies_df[['title_wiki','title_kaggle']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-62502164d674> in <module>
# ----> 1 movies_df[['title_wiki','title_kaggle']]
#
# NameError: name 'movies_df' is not defined
